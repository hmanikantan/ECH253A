# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as sp

# %%
x=np.linspace(-5,5,100)
yerf=sp.erf(x)
yerfc=sp.erfc(x)
plt.plot(x,yerf)
plt.plot(x,yerfc)
plt.grid('on')
plt.show()

# %%
# %matplotlib notebook
from ipywidgets import *


x = np.linspace(0, 10,1000)
fig = plt.figure(figsize=(3,6))
ax = fig.add_subplot(1, 1, 1)

nu=1
t=1
line, = ax.plot(sp.erfc(x/np.sqrt(nu*t)),x)

def update(t = 1.0):
    line.set_xdata(sp.erfc(x/np.sqrt(nu*t)))
    fig.canvas.draw_idle()

interact(update,t=widgets.FloatSlider(min=0.1, max=50, step=0.1, value=0.1));
# Out:
# <img src="data:image/png;base64,..." width="300">
# interactive(children=(FloatSlider(value=0.1, description='t', max=50.0, min=0.1), Output()), _dom_classes=('wi…

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

nu=1
t=0.1
X, Y = np.mgrid[:10:2,:6:0.5]
U = sp.erfc(Y/np.sqrt(nu*t))
V = 0.*Y

fig, ax = plt.subplots(1,1)
Q = ax.quiver(X, Y, U, V, color='r',scale=5)

ax.set_xlim(0, 10)
ax.set_ylim(0, 6)

def update_quiver(num, Q, Y, t):
    # updates the horizontal velocity at each frame
    U = sp.erfc(Y/np.sqrt(nu*(t + num*0.1)))
    V = 0.*Y
    Q.set_UVC(U,V)

    return Q,

anim = animation.FuncAnimation(fig, update_quiver, fargs=(Q, Y, t),frames=np.arange(0.0, 300, 1),
                               interval=50, blit=False, repeat=True)
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
